# %%
# Writing the below code to import the required packages and to show charts in the notebook itself
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Specifying the path to the csv file
wine_quality_data_path = 'E:\Verzeo- BA 2020\datasets_4458_8204_winequality-red.csv'

# %%
# Reading the csv file
wine_quality_data = pd.read_csv(data_path)
# First 10 rows of the dataframe
wine_quality_data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# Checking if any column has any null values
wine_quality_data.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
# Plotting a histogram representing fixed acidity from the sample data
sns.distplot(a= data['fixed acidity'], kde = False, bins = 10)

# %%
# Plotting a histogram representing chlorides conc from the sample data
sns.distplot(a= data['chlorides'], kde = False)

# %%
# Plotting a histogram representing citric acid conc from the sample data
sns.distplot(a= data['citric acid'], kde = False)

# %%
# Plotting a histogram representing density from the sample data
sns.distplot(a= data['density'], kde = False)

# %%
# Plotting a histogram representing pH from the sample data
sns.distplot(a= data['pH'], kde = False)

# %%
# Boxplot for fixed acidity column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('fixed acidity')

# %%
# Boxplot for volatile acidity column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('volatile acidity')

# %%
# Boxplot for citric acid column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('citric acid')

# %%
# Boxplot for residual sugar column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('residual sugar')

# %%
# Boxplot for chlorides column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('chlorides')

# %%
# Boxplot for free sulfur dioxide column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('free sulfur dioxide')

# %%
# Boxplot for total sulfur dioxide column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('total sulfur dioxide')

# %%
# Boxplot for density column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('density')

# %%
# Boxplot for pH column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('pH')

# %%
# Boxplot for free sulphates column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('sulphates')

# %%
# Boxplot for alcohol column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('alcohol')

# %%
# Boxplot for quality column from the sample data
plt.figure(figsize=(10,5))
data.boxplot('quality')

# %%
# Scatter plot drawn between pH and Density
plt.figure(figsize=(13,5))
sns.scatterplot(y = data['pH'], x = data['density'])

# %%
# Scatter plot drawn between Quality and Density
plt.figure(figsize=(10,5))
sns.scatterplot(y = data['density'], x = data['quality'])

# %%
# Scatter plot drawn between Alcohol and Density
plt.figure(figsize=(10,5))
sns.scatterplot(y = data['density'], x = data['alcohol'])

# %%
# Scatter plot drawn between total sulfur dioxide and free sulfur dioxide
plt.figure(figsize=(10,5))
sns.scatterplot(y = data['total sulfur dioxide'], x = data['free sulfur dioxide'])

# %%
# Scatter plot drawn between total sulfur dioxide and citric acid
plt.figure(figsize=(10,5))
sns.scatterplot(y = data['total sulfur dioxide'], x = data['citric acid'])

# %%
# Importing the required packages for Modelling

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
# Assigning the target variable
y = data['quality'].values

# Assigning the feature variable
X = data.drop('quality', axis = 1).values

# %%
# Using the train_test_split to split the data into 25% testsize and 75% trainsize
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.25, stratify = y)

# Instantiating the KNN Model
Knn = KNeighborsClassifier(n_neighbors = 4) 

# Fitting the data in the model
Knn.fit(X,y)

# Checking the score using the X_test and y_test
print(Knn.score(X_test, y_test))
# Out:
# 0.715
